# %% [markdown]
# <a href="https://colab.research.google.com/github/MajorFeijo/RNA-e-Deep-Learning-CESAR-School-2023.02/blob/main/Atividade%20Aula%204.3/4_3_Tinker_With_a_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Faça as atividades e responda as perguntas abaixo. Para submissão, submeta sua resposta no repositório criado para a disciplina.
#
# Coloque o resultado dentro de uma pasta chamada "Atividade Aula 4.3".
#
# 1. Acesse a página http://playground.tensorflow.org e utilizando apenas 2 entradas (x1 e x2), procure variar os
# diversos parâmetros:
#     - número de camadas
#     - número de neurônios em cada camada
#     - tipo de ativação
#     - learning rate
#     - fator de regularização
#
# Resolva para o dataset "Spiral".
#
# Coloque no notebook uma screenshot da tela com sua solução e comente sobre o que aprendeu nesse exercício (qual o impacto do número de camadas, neurônios em cada camada, ativação, learning rate e regularização).

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  # Print the image
  from IPython.display import Image
  display(Image(filename=fn))
# Out:
#      <input type="file" id="files-643b55bd-7cc2-4d2f-97d9-0523f7a3a281" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-643b55bd-7cc2-4d2f-97d9-0523f7a3a281">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Conclusões:
#
# ## Com poucas camadas de neuronios o modelo pode não ser capaz de aprender a relação não linear entre as entradas e saídas. À medida que o número de camadas aumenta, o modelo aumento o seu grau de complexidade e pode capturar relações mais complexas entre X e Y. Contudo, muitas camadas podem levar ao overfitting.
#
# ## Da mesma forma um número maior de neurônios por camada permite que o modelo aprenda relações mais complexas e também podem levar ao overfitting.
#
# ## A função de ativação ReLU que é frequentemente usada em redes neurais profundas mostrou os melhores resultados computacionais e de eficiência do modelo pois ele permite o Modelo aprender relações não lineares, sem as limitações na velocidade de convergencia do Sigmoid.
#
# ## O learning rate que determina a rapidez com que o modelo aprende teve seu valor ótimo em 0.03, valores acima deste apresentaram dificuldade de convergencia e abaixo velocidade extremamente baixa de convergência.
#
# ## Um learning rate muito alto pode levar ao overfitting, enquanto um learning rate muito baixo pode levar ao underfitting.
#
# # A regularização foi usada para evitar o overfitting "penalizando" a rede quando esta tem pesos grandes. Tornando a rede neural menos propensa a memorizar o conjunto de treinamento e mais propensa a generalizar. Foi utilizado a regularização L2 que : adiciona um termo de penalidade à função de custo da rede neural que é proporcional ao quadrado da magnitude dos pesos.
